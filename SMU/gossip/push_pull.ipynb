# %% [markdown]
# # Gossiping con protocolo push donde se converge al valor máximo
#
# El envio de mensajes es solo a un vecino aleatorio
#
# **Recuerda cambiar el nombre de los agentes**

# %%
import datetime
import json
import random
import time
import asyncio
import spade

class PushPullAgent(spade.agent.Agent):
    def __init__(self, jid, password, k, type=0):
        super().__init__(jid, password)
        self.k = k
        self.message_count = 0
        self.type = type

    async def setup(self):
        self.value = random.randint(1, 1000)
        start_at = datetime.datetime.now() + datetime.timedelta(seconds=5)
        
        # Comportamiento de Push: enviar valores a otros agentes
        self.add_behaviour(self.PushBehaviour(period=2, start_at=start_at))
        
        # Comportamiento de Pull: solicitar valores a otros agentes
        self.add_behaviour(self.PullBehaviour(period=2, start_at=start_at))

        # Template para gestionar solicitudes y respuestas
        template_request = spade.template.Template(metadata={"performative": "REQUEST"})
        template_response = spade.template.Template(metadata={"performative": "RESPONSE"})
        self.add_behaviour(self.RequestHandler(), template_request)
        self.add_behaviour(self.ResponseHandler(), template_response)

    def add_value(self, received_value):
        # Actualiza el valor tomando la media entre el valor propio y el recibido
        if self.type == 0:
            self.value = (self.value + received_value) / 2
        else:
            self.value = max(self.value, received_value)

    def add_contacts(self, contact_list):
        self.contacts = [c.jid for c in contact_list if c.jid != self.jid]
        self.length = len(self.contacts)
        if self.k > self.length:
            self.k = self.length

    # Comportamiento de Push: enviar valores a otros agentes
    class PushBehaviour(spade.behaviour.PeriodicBehaviour):
        async def run(self):
            k = self.agent.k
            random_contacts = random.sample(self.agent.contacts, k)
            
            # Enviar valor a contactos seleccionados
            for jid in random_contacts:
                body = json.dumps({"value": self.agent.value, "timestamp": time.time()})
                msg = spade.message.Message(to=str(jid), body=body, metadata={"performative": "PUSH"})
                await self.send(msg)
                self.agent.message_count += 1

    # Comportamiento de Pull: solicitar valores de otros agentes
    class PullBehaviour(spade.behaviour.PeriodicBehaviour):
        async def run(self):
            k = self.agent.k
            random_contacts = random.sample(self.agent.contacts, k)
            
            # Solicitar valores de contactos seleccionados
            for jid in random_contacts:
                msg = spade.message.Message(to=str(jid), metadata={"performative": "REQUEST"})
                await self.send(msg)
                self.agent.message_count += 1

    # Manejar solicitudes (REQUEST) y enviar respuestas (RESPONSE)
    class RequestHandler(spade.behaviour.CyclicBehaviour):
        async def run(self):
            msg = await self.receive(timeout=2)
            if msg:
                # Gestiona una solicitud y responde con el valor actual
                response = spade.message.Message(
                    to=str(msg.sender),
                    body=json.dumps({"value": self.agent.value}),
                    metadata={"performative": "RESPONSE"}
                )
                await self.send(response)
                self.agent.message_count += 1

    # Manejar respuestas (RESPONSE) y actualizar valor
    class ResponseHandler(spade.behaviour.CyclicBehaviour):
        async def run(self):
            msg = await self.receive(timeout=2)
            if msg:
                # Gestiona una respuesta y actualiza el valor del agente
                body = json.loads(msg.body)
                self.agent.add_value(body["value"])

# %%
# Parámetros del experimento
count = 50
k = 5
agents = []
print(f"Creando {count} agentes con k={k}")

# Crear agentes Push-Pull
for x in range(1, count + 1):
    agents.append(PushPullAgent(f"push_pull_agent_{x}@localhost", "test", k, type=1))

# Tiempo para permitir el registro
await asyncio.sleep(3)

# Añadir contactos a cada agente
for ag in agents:
    ag.add_contacts(agents)

# Lanzar agentes
tasks = [ag.start() for ag in agents]
await asyncio.gather(*tasks)

# Medir tiempo y mensajes
start_time = time.time()
while True:
    await asyncio.sleep(1)
    status = [ag.value for ag in agents]
    print(f"STATUS: {status}")
    if len(set(status)) <= 1:
        break
end_time = time.time()

# Calcular métricas
total_time = end_time - start_time
total_messages = sum(ag.message_count for ag in agents)

# Mostrar resultados
print(f"Gossip terminado en {total_time:.2f} seconds.")
print(f"Mensajes enviados {total_messages}.")

# Parar agentes
for ag in agents:
    await ag.stop()
print("Agentes parados")
# Out:
# Creando 50 agentes con k=5
# STATUS: [894, 918, 836, 918, 903, 989, 894, 699, 691, 989, 903, 918, 798, 918, 804, 911, 911, 804, 989, 903, 989, 918, 911, 903, 903, 911, 989, 918, 836, 903, 894, 911, 918, 903, 918, 903, 836, 989, 989, 911, 989, 536, 836, 918, 918, 918, 911, 989, 918, 680]
# STATUS: [894, 918, 836, 918, 903, 989, 894, 699, 691, 989, 903, 918, 798, 918, 804, 911, 911, 804, 989, 903, 989, 918, 911, 903, 903, 911, 989, 918, 836, 903, 894, 911, 918, 903, 918, 903, 836, 989, 989, 911, 989, 536, 836, 918, 918, 918, 911, 989, 918, 680]
# STATUS: [989, 989, 989, 918, 989, 989, 918, 989, 989, 989, 989, 989, 989, 989, 989, 989, 989, 989, 989, 989, 989, 989, 989, 989, 989, 989, 989, 989, 989, 918, 918, 989, 989, 989, 989, 918, 989, 989, 989, 989, 989, 918, 989, 989, 989, 989, 989, 989, 989, 989]
# STATUS: [989, 989, 989, 918, 989, 989, 918, 989, 989, 989, 989, 989, 989, 989, 989, 989, 989, 989, 989, 989, 989, 989, 989, 989, 989, 989, 989, 989, 989, 918, 918, 989, 989, 989, 989, 918, 989, 989, 989, 989, 989, 918, 989, 989, 989, 989, 989, 989, 989, 989]
# STATUS: [989, 989, 989, 989, 989, 989, 989, 989, 989, 989, 989, 989, 989, 989, 989, 989, 989, 989, 989, 989, 989, 989, 989, 989, 989, 989, 989, 989, 989, 989, 989, 989, 989, 989, 989, 989, 989, 989, 989, 989, 989, 989, 989, 989, 989, 989, 989, 989, 989, 989]
# Gossip terminado en 5.02 seconds.
# Mensajes enviados 1363.
# Agentes parados
# socket.send() raised exception.
# socket.send() raised exception.
# socket.send() raised exception.
# socket.send() raised exception.
# socket.send() raised exception.
# socket.send() raised exception.
# socket.send() raised exception.
# socket.send() raised exception.
# socket.send() raised exception.
# socket.send() raised exception.
# socket.send() raised exception.
# socket.send() raised exception.
# socket.send() raised exception.
# socket.send() raised exception.
# socket.send() raised exception.
# socket.send() raised exception.
# socket.send() raised exception.
# socket.send() raised exception.
# socket.send() raised exception.
# Future exception was never retrieved
# future: <Future finished exception=IqTimeout(<iq id="f546000cd969434eb26bea0a9b700f6c" type="get"><query xmlns="jabber:iq:roster" /></iq>)>
# slixmpp.exceptions.IqTimeout: <iq id="f546000cd969434eb26bea0a9b700f6c" type="get"><query xmlns="jabber:iq:roster" /></iq>
# Future exception was never retrieved
# future: <Future finished exception=IqTimeout(<iq id="9983e41a736f42dcabd3eb73eebe187d" type="get"><query xmlns="jabber:iq:roster" /></iq>)>
# slixmpp.exceptions.IqTimeout: <iq id="9983e41a736f42dcabd3eb73eebe187d" type="get"><query xmlns="jabber:iq:roster" /></iq>
# Future exception was never retrieved
# future: <Future finished exception=IqTimeout(<iq id="306bd1d9637b4b30b3730d85992c8c9f" type="get"><query xmlns="jabber:iq:roster" /></iq>)>
# slixmpp.exceptions.IqTimeout: <iq id="306bd1d9637b4b30b3730d85992c8c9f" type="get"><query xmlns="jabber:iq:roster" /></iq>
# Future exception was never retrieved
# future: <Future finished exception=IqTimeout(<iq id="1a2180a8d8084536bfcd77a16f147c0a" type="get"><query xmlns="jabber:iq:roster" /></iq>)>
# slixmpp.exceptions.IqTimeout: <iq id="1a2180a8d8084536bfcd77a16f147c0a" type="get"><query xmlns="jabber:iq:roster" /></iq>
# Future exception was never retrieved
# future: <Future finished exception=IqTimeout(<iq id="4b7480d8b6064ea984b7fee9baf154a2" type="get"><query xmlns="jabber:iq:roster" /></iq>)>
# slixmpp.exceptions.IqTimeout: <iq id="4b7480d8b6064ea984b7fee9baf154a2" type="get"><query xmlns="jabber:iq:roster" /></iq>
# Future exception was never retrieved
# future: <Future finished exception=IqTimeout(<iq id="04cee87405f24fa2a9cd282a13fc431b" type="get"><query xmlns="jabber:iq:roster" /></iq>)>
# slixmpp.exceptions.IqTimeout: <iq id="04cee87405f24fa2a9cd282a13fc431b" type="get"><query xmlns="jabber:iq:roster" /></iq>
# Future exception was never retrieved
# future: <Future finished exception=IqTimeout(<iq id="8a379cfa70c4400cbf860064f5efe1ab" type="get"><query xmlns="jabber:iq:roster" /></iq>)>
# slixmpp.exceptions.IqTimeout: <iq id="8a379cfa70c4400cbf860064f5efe1ab" type="get"><query xmlns="jabber:iq:roster" /></iq>
# Future exception was never retrieved
# future: <Future finished exception=IqTimeout(<iq id="b9104599074e48c4976051e99b6465b8" type="get"><query xmlns="jabber:iq:roster" /></iq>)>
# slixmpp.exceptions.IqTimeout: <iq id="b9104599074e48c4976051e99b6465b8" type="get"><query xmlns="jabber:iq:roster" /></iq>
# Future exception was never retrieved
# future: <Future finished exception=IqTimeout(<iq id="8ea2e4801e014b8ebcbcb6e5f0381302" type="get"><query xmlns="jabber:iq:roster" /></iq>)>
# slixmpp.exceptions.IqTimeout: <iq id="8ea2e4801e014b8ebcbcb6e5f0381302" type="get"><query xmlns="jabber:iq:roster" /></iq>
# Future exception was never retrieved
# future: <Future finished exception=IqTimeout(<iq id="794d7d7d4d75470c936aafa8a847837f" type="get"><query xmlns="jabber:iq:roster" /></iq>)>
# slixmpp.exceptions.IqTimeout: <iq id="794d7d7d4d75470c936aafa8a847837f" type="get"><query xmlns="jabber:iq:roster" /></iq>
# Future exception was never retrieved
# future: <Future finished exception=IqTimeout(<iq id="f582705dd5054bcb8c00ff8610d76d73" type="get"><query xmlns="jabber:iq:roster" /></iq>)>
# slixmpp.exceptions.IqTimeout: <iq id="f582705dd5054bcb8c00ff8610d76d73" type="get"><query xmlns="jabber:iq:roster" /></iq>
# Future exception was never retrieved
# future: <Future finished exception=IqTimeout(<iq id="b85447676a074e979e5e74f8c3d35d1d" type="get"><query xmlns="jabber:iq:roster" /></iq>)>
# slixmpp.exceptions.IqTimeout: <iq id="b85447676a074e979e5e74f8c3d35d1d" type="get"><query xmlns="jabber:iq:roster" /></iq>
# Future exception was never retrieved
# future: <Future finished exception=IqTimeout(<iq id="138f7dc6fcae4f1b8b80bc0999d02a0e" type="get"><query xmlns="jabber:iq:roster" /></iq>)>
# slixmpp.exceptions.IqTimeout: <iq id="138f7dc6fcae4f1b8b80bc0999d02a0e" type="get"><query xmlns="jabber:iq:roster" /></iq>
# Future exception was never retrieved
# future: <Future finished exception=IqTimeout(<iq id="0a206acb814d4e4d86d6b2d7a792b824" type="get"><query xmlns="jabber:iq:roster" /></iq>)>
# slixmpp.exceptions.IqTimeout: <iq id="0a206acb814d4e4d86d6b2d7a792b824" type="get"><query xmlns="jabber:iq:roster" /></iq>
# Future exception was never retrieved
# future: <Future finished exception=IqTimeout(<iq id="b9c6804672e841019303daae2ec182ca" type="get"><query xmlns="jabber:iq:roster" /></iq>)>
# slixmpp.exceptions.IqTimeout: <iq id="b9c6804672e841019303daae2ec182ca" type="get"><query xmlns="jabber:iq:roster" /></iq>
# Future exception was never retrieved
# future: <Future finished exception=IqTimeout(<iq id="cdefbba366c44aa298d3b5d465dc8df7" type="get"><query xmlns="jabber:iq:roster" /></iq>)>
# slixmpp.exceptions.IqTimeout: <iq id="cdefbba366c44aa298d3b5d465dc8df7" type="get"><query xmlns="jabber:iq:roster" /></iq>
# Future exception was never retrieved
# future: <Future finished exception=IqTimeout(<iq id="d1f22bb9d5fc496d8e4b0dee18a971ec" type="get"><query xmlns="jabber:iq:roster" /></iq>)>
# slixmpp.exceptions.IqTimeout: <iq id="d1f22bb9d5fc496d8e4b0dee18a971ec" type="get"><query xmlns="jabber:iq:roster" /></iq>
# Future exception was never retrieved
# future: <Future finished exception=IqTimeout(<iq id="6a0b01739c0e4cfcbdbe0821a1a30620" type="get"><query xmlns="jabber:iq:roster" /></iq>)>
# slixmpp.exceptions.IqTimeout: <iq id="6a0b01739c0e4cfcbdbe0821a1a30620" type="get"><query xmlns="jabber:iq:roster" /></iq>
# Future exception was never retrieved
# future: <Future finished exception=IqTimeout(<iq id="f9f4c03d7c504b0f967bd9ab74e0d427" type="get"><query xmlns="jabber:iq:roster" /></iq>)>
# slixmpp.exceptions.IqTimeout: <iq id="f9f4c03d7c504b0f967bd9ab74e0d427" type="get"><query xmlns="jabber:iq:roster" /></iq>
# Future exception was never retrieved
# future: <Future finished exception=IqTimeout(<iq id="7f9ab49f25904709ba40fcf8409d6936" type="get"><query xmlns="jabber:iq:roster" /></iq>)>
# slixmpp.exceptions.IqTimeout: <iq id="7f9ab49f25904709ba40fcf8409d6936" type="get"><query xmlns="jabber:iq:roster" /></iq>
# Future exception was never retrieved
# future: <Future finished exception=IqTimeout(<iq id="cc57b180da774ead824d3215dc8f1ae2" type="get"><query xmlns="jabber:iq:roster" /></iq>)>
# slixmpp.exceptions.IqTimeout: <iq id="cc57b180da774ead824d3215dc8f1ae2" type="get"><query xmlns="jabber:iq:roster" /></iq>
# Future exception was never retrieved
# future: <Future finished exception=IqTimeout(<iq id="b5d0408f2e0643dca52565b1665ce412" type="get"><query xmlns="jabber:iq:roster" /></iq>)>
# slixmpp.exceptions.IqTimeout: <iq id="b5d0408f2e0643dca52565b1665ce412" type="get"><query xmlns="jabber:iq:roster" /></iq>
# Future exception was never retrieved
# future: <Future finished exception=IqTimeout(<iq id="d15f1164187a49db975d567b99db8a43" type="get"><query xmlns="jabber:iq:roster" /></iq>)>
# slixmpp.exceptions.IqTimeout: <iq id="d15f1164187a49db975d567b99db8a43" type="get"><query xmlns="jabber:iq:roster" /></iq>
# Future exception was never retrieved
# future: <Future finished exception=IqTimeout(<iq id="faeb4a21cc674b36927062ca41d84ecf" type="get"><query xmlns="jabber:iq:roster" /></iq>)>
# slixmpp.exceptions.IqTimeout: <iq id="faeb4a21cc674b36927062ca41d84ecf" type="get"><query xmlns="jabber:iq:roster" /></iq>
# Future exception was never retrieved
# future: <Future finished exception=IqTimeout(<iq id="2b1b448a586248edabcc6872253c681b" type="get"><query xmlns="jabber:iq:roster" /></iq>)>
# slixmpp.exceptions.IqTimeout: <iq id="2b1b448a586248edabcc6872253c681b" type="get"><query xmlns="jabber:iq:roster" /></iq>
# Future exception was never retrieved
# future: <Future finished exception=IqTimeout(<iq id="0489c6d708e544c5aff6c44496166785" type="get"><query xmlns="jabber:iq:roster" /></iq>)>
# slixmpp.exceptions.IqTimeout: <iq id="0489c6d708e544c5aff6c44496166785" type="get"><query xmlns="jabber:iq:roster" /></iq>
# Future exception was never retrieved
# future: <Future finished exception=IqTimeout(<iq id="1541ba3d243c45db95edcbd8196c356b" type="get"><query xmlns="jabber:iq:roster" /></iq>)>
# slixmpp.exceptions.IqTimeout: <iq id="1541ba3d243c45db95edcbd8196c356b" type="get"><query xmlns="jabber:iq:roster" /></iq>
# socket.send() raised exception.
# socket.send() raised exception.
# socket.send() raised exception.
# socket.send() raised exception.
# socket.send() raised exception.
# socket.send() raised exception.
# socket.send() raised exception.
# socket.send() raised exception.
# socket.send() raised exception.
# socket.send() raised exception.
# socket.send() raised exception.
# socket.send() raised exception.
# socket.send() raised exception.
# socket.send() raised exception.
# socket.send() raised exception.
# socket.send() raised exception.
# socket.send() raised exception.
# socket.send() raised exception.
# socket.send() raised exception.
# socket.send() raised exception.
# socket.send() raised exception.
# socket.send() raised exception.
# socket.send() raised exception.
# socket.send() raised exception.
# socket.send() raised exception.
# socket.send() raised exception.
# socket.send() raised exception.
# socket.send() raised exception.
# socket.send() raised exception.
# socket.send() raised exception.
# socket.send() raised exception.
# socket.send() raised exception.
# socket.send() raised exception.
# socket.send() raised exception.
# socket.send() raised exception.
# socket.send() raised exception.
# socket.send() raised exception.
# socket.send() raised exception.
# socket.send() raised exception.
# socket.send() raised exception.
# socket.send() raised exception.
# socket.send() raised exception.
# socket.send() raised exception.
# socket.send() raised exception.
# socket.send() raised exception.
# socket.send() raised exception.
# socket.send() raised exception.
# socket.send() raised exception.
# socket.send() raised exception.
# socket.send() raised exception.
# socket.send() raised exception.
# socket.send() raised exception.
# socket.send() raised exception.
# socket.send() raised exception.
# socket.send() raised exception.
# socket.send() raised exception.
# socket.send() raised exception.

# %%
# Parámetros del experimento
count = 50
k = 5
agents = []
print(f"Creando {count} agentes con k={k}")

# Crear agentes Push-Pull
for x in range(1, count + 1):
    agents.append(PushPullAgent(f"push_pull_agent_{x}@localhost", "test", k, type=0))

# Tiempo para permitir el registro
await asyncio.sleep(3)

# Añadir contactos a cada agente
for ag in agents:
    ag.add_contacts(agents)

# Lanzar agentes
tasks = [ag.start() for ag in agents]
await asyncio.gather(*tasks)

# Medir tiempo y mensajes
start_time = time.time()
while True:
    await asyncio.sleep(1)
    status = [ag.value for ag in agents]
    print(f"STATUS: {status}")
    if len(set(status)) <= 1:
        break
end_time = time.time()

# Calcular métricas
total_time = end_time - start_time
total_messages = sum(ag.message_count for ag in agents)

# Mostrar resultados
print(f"Gossip terminado en {total_time:.2f} seconds.")
print(f"Mensajes enviados {total_messages}.")

# Parar agentes
for ag in agents:
    await ag.stop()
print("Agentes parados")
# Out:
# Creando 50 agentes con k=5
# STATUS: [312, 364, 960, 886, 974, 680, 566, 217, 265, 10, 979, 309, 622, 714, 482, 997, 908, 924, 955, 855, 995, 236, 499, 840, 259, 863, 484, 220, 863, 130, 807, 869, 806, 38, 78, 220, 173, 324, 258, 840, 837, 590, 162, 969, 394, 71, 33, 982, 524, 404]
# STATUS: [312, 364, 960, 886, 974, 680, 566, 217, 265, 10, 979, 309, 622, 714, 482, 997, 908, 924, 955, 855, 995, 236, 499, 840, 259, 863, 484, 220, 863, 130, 807, 869, 806, 38, 78, 220, 173, 324, 258, 840, 837, 590, 162, 969, 394, 71, 33, 982, 524, 404]
# STATUS: [481.3826315032642, 478.87192381600426, 480.0000909258338, 477.70959071806624, 478.604237184902, 480.49250371806323, 479.8202593749121, 478.5240059131463, 476.9950326417685, 477.8545476009622, 479.8814487139343, 478.2616209845337, 479.86336396301135, 479.73847419584513, 481.5219381945648, 477.64633986414947, 478.526939431509, 478.4362384559482, 482.0045376776094, 479.1790331827484, 478.1054195080624, 479.7711849385147, 477.581654117708, 478.47963782812474, 478.7631074723843, 477.09320598338786, 479.19909724708697, 478.137098055808, 478.7036557940985, 479.71448504069207, 477.75603232146113, 478.13915836832405, 479.3028723754245, 478.4210681312101, 479.61256245566926, 479.00917928370495, 478.7374739873088, 479.1529935578199, 479.20176107923066, 478.0792704043576, 479.10813777778105, 479.14419512542435, 477.2915512381171, 478.03145694210144, 478.61245550485955, 478.0091431308449, 478.74280321947026, 479.13648789718025, 478.3917119835655, 478.3706173334689]
# STATUS: [478.96747745529785, 479.1545088344844, 479.28405869040955, 479.3454954838427, 478.9709192216777, 478.79427461471374, 478.96761657570516, 478.6321229992956, 479.071620821996, 479.19952125156357, 479.01758794771945, 478.64166440877733, 478.86274848734274, 479.6110313905601, 480.4526950051748, 478.89311869808523, 478.5143481266475, 478.52646746769284, 478.4534000793144, 478.73602944473345, 478.76268842665945, 480.25877785124226, 478.8650923019073, 479.0614496021694, 478.46162207889824, 477.55208530934897, 478.85099293976555, 478.9500946184917, 478.4500077904081, 478.69069522374167, 478.5149740733145, 478.82005640938905, 478.53276269563924, 479.58167549906625, 478.64819101638693, 478.5124872529874, 478.8552521676986, 478.70041210975285, 479.4764848461841, 478.8003893603334, 478.5167960119578, 478.34945730573804, 478.8990499549867, 478.63910432367254, 479.52949368152986, 479.6375019445712, 479.4376153578796, 479.5752707906279, 479.08927252825754, 479.6462904051324]
# ---------------------------------------------------------------------------
# CancelledError                            Traceback (most recent call last)
# Cell In[2], line 25
#      23 start_time = time.time()
#      24 while True:
# ---> 25     await asyncio.sleep(1)
#      26     status = [ag.value for ag in agents]
#      27     print(f"STATUS: {status}")
#
# File /opt/homebrew/Cellar/python@3.10/3.10.16/Frameworks/Python.framework/Versions/3.10/lib/python3.10/asyncio/tasks.py:605, in sleep(delay, result)
#     601 h = loop.call_later(delay,
#     602                     futures._set_result_unless_cancelled,
#     603                     future, result)
#     604 try:
# --> 605     return await future
#     606 finally:
#     607     h.cancel()
#
# CancelledError:

# %%
async def run_agents(t,k=2,a=50, path="result_push_pull.txt"):
    agents = []
    print(f"Creando {a} agentes con k={k} en type {t}")

    # Crear agentes Push-Pull
    for x in range(1, a + 1):
        agents.append(PushPullAgent(f"pull_agent_{x}@localhost", "test", k, type=t))

    # Tiempo para permitir el registro
    await asyncio.sleep(3)

    # Añadir contactos a cada agente
    for ag in agents:
        ag.add_contacts(agents)

    # Lanzar agentes
    tasks = [ag.start() for ag in agents]
    await asyncio.gather(*tasks)

    # Medir tiempo y mensajes
    start_time = time.time()
    while True:
        await asyncio.sleep(1)
        status = [ag.value for ag in agents]
        if len(set(status)) <= 1:
            break
    end_time = time.time()

    # Calcular métricas
    total_time = end_time - start_time
    total_messages = sum(ag.message_count for ag in agents)

    with open(path,"a") as f:
        f.write(f"{t},{k},{a},{total_messages},{total_time}\n")

    # Mostrar resultados
    print(f"Gossip terminado en {total_time:.2f} seconds.")
    print(f"Mensajes enviados {total_messages}.")

    # Parar agentes
    for ag in agents:
        await ag.stop()
    print("Agentes parados")

# %%
for t in [1]:
     for k in [1,3,5,10]:
         await run_agents(t, k=k)
         await asyncio.sleep(1)
        
    #for ag in [10,20,50,100,200]:
    #    await run_agents(t=t,a=ag)
    #    await asyncio.sleep(2)
# Out:
# Creando 50 agentes con k=1 en type 1
# Gossip terminado en 21.01 seconds.
# Mensajes enviados 1350.
# Agentes parados
# Creando 50 agentes con k=3 en type 1
# Gossip terminado en 13.03 seconds.
# Mensajes enviados 2228.
# Agentes parados
# Creando 50 agentes con k=5 en type 1
# Gossip terminado en 10.03 seconds.
# Mensajes enviados 2250.
# Agentes parados
# Creando 50 agentes con k=10 en type 1
# No behaviour matched for message: <message to="pull_agent_2@localhost" from="pull_agent_9@localhost" thread="None" metadata={'performative': 'PUSH'}>
# {"value": 978, "timestamp": 1736356091.6241221}
# </message>
# No behaviour matched for message: <message to="pull_agent_3@localhost" from="pull_agent_6@localhost" thread="None" metadata={'performative': 'PUSH'}>
# {"value": 978, "timestamp": 1736356091.642802}
# </message>
# No behaviour matched for message: <message to="pull_agent_3@localhost" from="pull_agent_23@localhost" thread="None" metadata={'performative': 'PUSH'}>
# {"value": 978, "timestamp": 1736356091.6451929}
# </message>
# No behaviour matched for message: <message to="pull_agent_3@localhost" from="pull_agent_18@localhost" thread="None" metadata={'performative': 'PUSH'}>
# {"value": 978, "timestamp": 1736356091.646347}
# </message>
# No behaviour matched for message: <message to="pull_agent_2@localhost" from="pull_agent_18@localhost" thread="None" metadata={'performative': 'PUSH'}>
# {"value": 978, "timestamp": 1736356091.647243}
# </message>
# No behaviour matched for message: <message to="pull_agent_2@localhost" from="pull_agent_8@localhost" thread="None" metadata={'performative': 'PUSH'}>
# {"value": 978, "timestamp": 1736356091.655384}
# </message>
# No behaviour matched for message: <message to="pull_agent_2@localhost" from="pull_agent_12@localhost" thread="None" metadata={'performative': 'PUSH'}>
# {"value": 978, "timestamp": 1736356091.657225}
# </message>
# No behaviour matched for message: <message to="pull_agent_3@localhost" from="pull_agent_10@localhost" thread="None" metadata={'performative': 'PUSH'}>
# {"value": 978, "timestamp": 1736356091.658864}
# </message>
# No behaviour matched for message: <message to="pull_agent_2@localhost" from="pull_agent_20@localhost" thread="None" metadata={'performative': 'PUSH'}>
# {"value": 978, "timestamp": 1736356091.660351}
# </message>
# No behaviour matched for message: <message to="pull_agent_2@localhost" from="pull_agent_13@localhost" thread="None" metadata={'performative': 'PUSH'}>
# {"value": 978, "timestamp": 1736356091.661422}
# </message>
# No behaviour matched for message: <message to="pull_agent_2@localhost" from="pull_agent_21@localhost" thread="None" metadata={'performative': 'PUSH'}>
# {"value": 978, "timestamp": 1736356091.669801}
# </message>
# No behaviour matched for message: <message to="pull_agent_2@localhost" from="pull_agent_19@localhost" thread="None" metadata={'performative': 'PUSH'}>
# {"value": 978, "timestamp": 1736356091.670499}
# </message>
# No behaviour matched for message: <message to="pull_agent_3@localhost" from="pull_agent_11@localhost" thread="None" metadata={'performative': 'PUSH'}>
# {"value": 978, "timestamp": 1736356091.6719449}
# </message>
# No behaviour matched for message: <message to="pull_agent_2@localhost" from="pull_agent_7@localhost" thread="None" metadata={'performative': 'PUSH'}>
# {"value": 978, "timestamp": 1736356091.672962}
# </message>
# No behaviour matched for message: <message to="pull_agent_5@localhost" from="pull_agent_24@localhost" thread="None" metadata={'performative': 'REQUEST'}></message>
# No behaviour matched for message: <message to="pull_agent_2@localhost" from="pull_agent_32@localhost" thread="None" metadata={'performative': 'REQUEST'}></message>
# No behaviour matched for message: <message to="pull_agent_2@localhost" from="pull_agent_45@localhost" thread="None" metadata={'performative': 'PUSH'}>
# {"value": 978, "timestamp": 1736356091.676283}
# </message>
# No behaviour matched for message: <message to="pull_agent_5@localhost" from="pull_agent_45@localhost" thread="None" metadata={'performative': 'REQUEST'}></message>
# No behaviour matched for message: <message to="pull_agent_3@localhost" from="pull_agent_30@localhost" thread="None" metadata={'performative': 'REQUEST'}></message>
# No behaviour matched for message: <message to="pull_agent_3@localhost" from="pull_agent_30@localhost" thread="None" metadata={'performative': 'PUSH'}>
# {"value": 978, "timestamp": 1736356091.6878898}
# </message>
# No behaviour matched for message: <message to="pull_agent_5@localhost" from="pull_agent_26@localhost" thread="None" metadata={'performative': 'REQUEST'}></message>
# No behaviour matched for message: <message to="pull_agent_2@localhost" from="pull_agent_26@localhost" thread="None" metadata={'performative': 'REQUEST'}></message>
# No behaviour matched for message: <message to="pull_agent_3@localhost" from="pull_agent_48@localhost" thread="None" metadata={'performative': 'PUSH'}>
# {"value": 978, "timestamp": 1736356091.696631}
# </message>
# No behaviour matched for message: <message to="pull_agent_5@localhost" from="pull_agent_35@localhost" thread="None" metadata={'performative': 'REQUEST'}></message>
# No behaviour matched for message: <message to="pull_agent_2@localhost" from="pull_agent_41@localhost" thread="None" metadata={'performative': 'PUSH'}>
# {"value": 978, "timestamp": 1736356091.710043}
# </message>
# No behaviour matched for message: <message to="pull_agent_3@localhost" from="pull_agent_33@localhost" thread="None" metadata={'performative': 'REQUEST'}></message>
# No behaviour matched for message: <message to="pull_agent_3@localhost" from="pull_agent_33@localhost" thread="None" metadata={'performative': 'PUSH'}>
# {"value": 978, "timestamp": 1736356091.717143}
# </message>
# No behaviour matched for message: <message to="pull_agent_5@localhost" from="pull_agent_33@localhost" thread="None" metadata={'performative': 'PUSH'}>
# {"value": 978, "timestamp": 1736356091.718693}
# </message>
# No behaviour matched for message: <message to="pull_agent_5@localhost" from="pull_agent_43@localhost" thread="None" metadata={'performative': 'REQUEST'}></message>
# No behaviour matched for message: <message to="pull_agent_3@localhost" from="pull_agent_43@localhost" thread="None" metadata={'performative': 'PUSH'}>
# {"value": 978, "timestamp": 1736356091.7252421}
# </message>
# No behaviour matched for message: <message to="pull_agent_2@localhost" from="pull_agent_38@localhost" thread="None" metadata={'performative': 'PUSH'}>
# {"value": 978, "timestamp": 1736356091.730031}
# </message>
# No behaviour matched for message: <message to="pull_agent_5@localhost" from="pull_agent_39@localhost" thread="None" metadata={'performative': 'PUSH'}>
# {"value": 978, "timestamp": 1736356091.732783}
# </message>
# No behaviour matched for message: <message to="pull_agent_5@localhost" from="pull_agent_39@localhost" thread="None" metadata={'performative': 'REQUEST'}></message>
# No behaviour matched for message: <message to="pull_agent_3@localhost" from="pull_agent_40@localhost" thread="None" metadata={'performative': 'PUSH'}>
# {"value": 978, "timestamp": 1736356091.73956}
# </message>
# No behaviour matched for message: <message to="pull_agent_5@localhost" from="pull_agent_40@localhost" thread="None" metadata={'performative': 'PUSH'}>
# {"value": 978, "timestamp": 1736356091.741308}
# </message>
# No behaviour matched for message: <message to="pull_agent_2@localhost" from="pull_agent_40@localhost" thread="None" metadata={'performative': 'REQUEST'}></message>
# No behaviour matched for message: <message to="pull_agent_3@localhost" from="pull_agent_40@localhost" thread="None" metadata={'performative': 'REQUEST'}></message>
# No behaviour matched for message: <message to="pull_agent_5@localhost" from="pull_agent_49@localhost" thread="None" metadata={'performative': 'REQUEST'}></message>
# No behaviour matched for message: <message to="pull_agent_2@localhost" from="pull_agent_49@localhost" thread="None" metadata={'performative': 'PUSH'}>
# {"value": 978, "timestamp": 1736356091.750124}
# </message>
# No behaviour matched for message: <message to="pull_agent_2@localhost" from="pull_agent_47@localhost" thread="None" metadata={'performative': 'PUSH'}>
# {"value": 978, "timestamp": 1736356091.75767}
# </message>
# No behaviour matched for message: <message to="pull_agent_2@localhost" from="pull_agent_46@localhost" thread="None" metadata={'performative': 'PUSH'}>
# {"value": 978, "timestamp": 1736356091.7607849}
# </message>
# No behaviour matched for message: <message to="pull_agent_5@localhost" from="pull_agent_46@localhost" thread="None" metadata={'performative': 'PUSH'}>
# {"value": 978, "timestamp": 1736356091.7616498}
# </message>
# No behaviour matched for message: <message to="pull_agent_5@localhost" from="pull_agent_44@localhost" thread="None" metadata={'performative': 'PUSH'}>
# {"value": 978, "timestamp": 1736356091.764054}
# </message>
# No behaviour matched for message: <message to="pull_agent_5@localhost" from="pull_agent_37@localhost" thread="None" metadata={'performative': 'REQUEST'}></message>
# No behaviour matched for message: <message to="pull_agent_2@localhost" from="pull_agent_37@localhost" thread="None" metadata={'performative': 'REQUEST'}></message>
# No behaviour matched for message: <message to="pull_agent_1@localhost" from="pull_agent_37@localhost" thread="None" metadata={'performative': 'PUSH'}>
# {"value": 978, "timestamp": 1736356091.766932}
# </message>
# No behaviour matched for message: <message to="pull_agent_2@localhost" from="pull_agent_42@localhost" thread="None" metadata={'performative': 'PUSH'}>
# {"value": 978, "timestamp": 1736356091.769129}
# </message>
# No behaviour matched for message: <message to="pull_agent_5@localhost" from="pull_agent_42@localhost" thread="None" metadata={'performative': 'PUSH'}>
# {"value": 978, "timestamp": 1736356091.77022}
# </message>
# No behaviour matched for message: <message to="pull_agent_2@localhost" from="pull_agent_50@localhost" thread="None" metadata={'performative': 'PUSH'}>
# {"value": 978, "timestamp": 1736356091.77359}
# </message>
# No behaviour matched for message: <message to="pull_agent_5@localhost" from="pull_agent_34@localhost" thread="None" metadata={'performative': 'REQUEST'}></message>
# No behaviour matched for message: <message to="pull_agent_3@localhost" from="pull_agent_34@localhost" thread="None" metadata={'performative': 'PUSH'}>
# {"value": 978, "timestamp": 1736356091.777129}
# </message>
# No behaviour matched for message: <message to="pull_agent_2@localhost" from="pull_agent_34@localhost" thread="None" metadata={'performative': 'PUSH'}>
# {"value": 978, "timestamp": 1736356091.7787452}
# </message>
# Gossip terminado en 8.93 seconds.
# Mensajes enviados 3000.
# Agentes parados

# %%
for t in [0]:
    for k in [1,3,5,10]:
        await run_agents(t, k=k)
        await asyncio.sleep(2)
# Out:
# Creando 50 agentes con k=1 en type 0
# Gossip terminado en 195.53 seconds.
# Mensajes enviados 14400.
# Agentes parados
# Creando 50 agentes con k=3 en type 0
# Gossip terminado en 103.35 seconds.
# Mensajes enviados 22500.
# Agentes parados
# Creando 50 agentes con k=5 en type 0
# Gossip terminado en 79.46 seconds.
# Mensajes enviados 28500.
# Agentes parados
# Creando 50 agentes con k=10 en type 0
# Gossip terminado en 73.51 seconds.
# Mensajes enviados 52500.
# Agentes parados

# %%
for t in [0]:
    for ag in [10,20,50]:
        await run_agents(t=t,a=ag)
        await asyncio.sleep(1)
# Out:
# Creando 10 agentes con k=2 en type 0
# Gossip terminado en 91.15 seconds.
# Mensajes enviados 2640.
# Agentes parados
# Creando 20 agentes con k=2 en type 0
# Gossip terminado en 107.13 seconds.
# Mensajes enviados 6240.
# Agentes parados
# Creando 50 agentes con k=2 en type 0
# Gossip terminado en 111.52 seconds.
# Mensajes enviados 16200.
# Agentes parados

# %%
await run_agents(0,a=100)
# Out:
# Creando 100 agentes con k=2 en type 0
# Gossip terminado en 121.80 seconds.
# Mensajes enviados 35400.
# Agentes parados

# %%
await run_agents(0,a=200)
